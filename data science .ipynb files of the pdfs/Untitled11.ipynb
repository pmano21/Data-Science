# %% [markdown]
# **P Manohar Rao**

# %% [markdown]
# **Roll no: 197158**

# %% [markdown]
# **DATA SCIENCE MIDLAB Q2**

# %%
#importing random 
import random
from random import randint
#creating a lsit to get the randomly generated no's into it
l=[]
#ruuning a loop to get randomly generated no's in a particular intervel given in the question
for i in range(3, 13):
    #appending the randomly generated no's in to list using append 
    l.append(random.randint(1, i))
#printing the list which we have got by appending the randomly generated no's
print(l)
# Out:
# [1, 3, 2, 1, 2, 3, 8, 10, 7, 2]
