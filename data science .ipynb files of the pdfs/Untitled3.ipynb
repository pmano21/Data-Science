# %%
l=[1,2,3,4.1,5.12,6.123,'NITW','CSE','Warangal']
l
# Out:
# [1, 2, 3, 4.1, 5.12, 6.123, 'NITW', 'CSE', 'Warangal']

# %%
s={1,2,3,4,5}

# %%
print("length of the list is ",len(l))
# Out:
# length of the list is  9

# %%
print("last element  of the list is ",l[-1])
# Out:
# last element  of the list is  Warangal

# %%
l.append('Telangana')
l
# Out:
# [1,
#  2,
#  3,
#  4.1,
#  5.12,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana']

# %%
l1=['Pincode',506001,'India']
l.extend(l1)
l
# Out:
# [1,
#  2,
#  3,
#  4.1,
#  5.12,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana',
#  'Pincode',
#  506001,
#  'India']

# %%
l.append(l1)
l.remove(l1)
l
# Out:
# [1,
#  2,
#  3,
#  4.1,
#  5.12,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana',
#  'Pincode',
#  506001,
#  'India',
#  ['Pincode', 506001, 'India'],
#  ['Pincode', 506001, 'India'],
#  ['Pincode', 506001, 'India']]

# %%
l.remove(l1)
l
# Out:
# [1,
#  2,
#  3,
#  4.1,
#  5.12,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana',
#  'Pincode',
#  506001,
#  'India',
#  ['Pincode', 506001, 'India'],
#  ['Pincode', 506001, 'India']]

# %%
l.append(l1)
l
# Out:
# [1,
#  2,
#  3,
#  4.1,
#  5.12,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana',
#  'Pincode',
#  506001,
#  'India',
#  ['Pincode', 506001, 'India']]

# %%
l
# Out:
# [1,
#  2,
#  3,
#  4.1,
#  5.12,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana',
#  'Pincode',
#  506001,
#  'India',
#  ['Pincode', 506001, 'India']]

# %%
l[0:4] # 0 to 3
# Out:
# [1, 2, 3, 4.1]

# %%
l[3:6] # 3 to 5
# Out:
# [4.1, 5.12, 6.123]

# %%
l[5:9] # 5 to 8
# Out:
# [6.123, 'NITW', 'CSE', 'Warangal']

# %%
l.insert(0,0) # adding 0 at index 0
l
# Out:
# [0,
#  1,
#  2,
#  3,
#  4.1,
#  5.12,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana',
#  'Pincode',
#  506001,
#  'India',
#  ['Pincode', 506001, 'India']]

# %%
l[5]=5.1122
l
# Out:
# [0,
#  1,
#  2,
#  3,
#  4.1,
#  5.1122,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana',
#  'Pincode',
#  506001,
#  'India',
#  ['Pincode', 506001, 'India']]

# %%
l.insert(5,2)
l.insert(4,2)
l
# Out:
# [0,
#  1,
#  2,
#  3,
#  2,
#  4.1,
#  2,
#  5.1122,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana',
#  'Pincode',
#  506001,
#  'India',
#  ['Pincode', 506001, 'India']]

# %%
l.pop(4)
l
# Out:
# [0,
#  1,
#  2,
#  3,
#  4.1,
#  2,
#  5.1122,
#  6.123,
#  'NITW',
#  'CSE',
#  'Warangal',
#  'Telangana',
#  'Telangana',
#  'Pincode',
#  506001,
#  'India',
#  ['Pincode', 506001, 'India']]

# %%
l2=l[0:8]
l2.sort()
l2
# Out:
# [0, 1, 2, 2, 3, 4.1, 5.1122, 6.123]

# %%
l.reverse()
l
# Out:
# [['Pincode', 506001, 'India'],
#  'India',
#  506001,
#  'Pincode',
#  'Telangana',
#  'Telangana',
#  'Warangal',
#  'CSE',
#  'NITW',
#  6.123,
#  5.1122,
#  2,
#  4.1,
#  3,
#  2,
#  1,
#  0]

# %%
t1=(1,2,7.1,6.23,'tuples',1,'python',2,1,1)
t1
# Out:
# (1, 2, 7.1, 6.23, 'tuples', 1, 'python', 2, 1, 1)

# %%
t1.count(2)
# Out:
# 2

# %%
t1.index(2)
# Out:
# 1

# %%
s1=set([1,2,8,6,3,4,7])
s1
# Out:
# {1, 2, 3, 4, 6, 7, 8}

# %%
s2={5,6,3,2,1,4,5,8,11,2,3,7,5}
s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 11}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 11}

# %%
s1.intersection(s2)
# Out:
# {1, 2, 3, 4, 6, 7, 8}

# %%
s1.add(10)
s1
# Out:
# {1, 2, 3, 4, 6, 7, 8, 10}

# %%
s2.update()
s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 11}

# %%
s1.difference(s2)
# Out:
# {10}

# %%
s1.symmetric_difference(s2)
# Out:
# {5, 10, 11}
