# %% [markdown]
# # Data Science Lab Assignment 8
# Name:P Manohar Rao
#
# Roll No: 197158
#
# Section: CSE-A

# %% [markdown]
# Implement neural network from scratch using python for the following datasets and predict the values for the following datasets:
#
# 1. Boston House prices dataset: https://www.kaggle.com/fedesoriano/the-boston-houseprice-data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

def relu(z):
    a = np.maximum(0,z)
    return a

def initialize_params(layer_sizes):
    params = {}
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

def forward_propagation(X_train, params):
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = relu(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = relu(values['Z' + str(i)])
    return values

def compute_cost(values, Y_train):
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

def backward_propagation(params, values, X_train, Y_train):
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

def update_params(params, grads, learning_rate):
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    params = initialize_params(layer_sizes)
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_cost(values, Y_train.T)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
    test_acc = np.sqrt(mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T))
    return train_acc, test_acc

def predict(X, params):
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

# %%
#Question 1
#predict the values for Boston House prices dataset
num_iters = 1000                                                                   
learning_rate = 0.03
layer_sizes=[13,5,5,1]
df =  pd.read_csv('boston.csv')
df.head()
n=df.shape[1]                
m=df.shape[0]               

x_train=np.array(df.iloc[:int(0.9*m),:n-1])      
y_train=np.array(df.iloc[:int(0.9*m),-1])          
x_test=np.array(df.iloc[int(0.9*m):,:n-1])        
y_test=np.array(df.iloc[int(0.9*m):,-1])          
params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)
y_predict = predict(x_test,params)
print(y_predict)
# Out:
# Cost at iteration 1 = 308.06672622008676
#
# Cost at iteration 2 = 308.02967784559854
#
# Cost at iteration 3 = 307.99257119445514
#
# Cost at iteration 4 = 307.95539871422227
#
# Cost at iteration 5 = 307.9181691096535
#
# Cost at iteration 6 = 307.88091958144264
#
# Cost at iteration 7 = 307.843737865762
#
# Cost at iteration 8 = 307.8067619890095
#
# Cost at iteration 9 = 307.7700494822006
#
# Cost at iteration 10 = 307.7334196203758
#
# Cost at iteration 11 = 307.69683637980916
#
# Cost at iteration 12 = 307.66023688016577
#
# Cost at iteration 13 = 307.62356675650597
#
# Cost at iteration 14 = 307.58678989738075
#
# Cost at iteration 15 = 307.5498866079032
#
# Cost at iteration 16 = 307.5128468308146
#
# Cost at iteration 17 = 307.4756592080321
#
# Cost at iteration 18 = 307.438311358209
#
# Cost at iteration 19 = 307.4007900500335
#
# Cost at iteration 20 = 307.3630806107037
#
# Cost at iteration 21 = 307.3251669239254
#
# Cost at iteration 22 = 307.28703099971017
#
# Cost at iteration 23 = 307.2486535213563
#
# Cost at iteration 24 = 307.21001315688676
#
# Cost at iteration 25 = 307.17108621854186
#
# Cost at iteration 26 = 307.1318466004275
#
# Cost at iteration 27 = 307.09226297206936
#
# Cost at iteration 28 = 307.052303676495
#
# Cost at iteration 29 = 307.0119325570409
#
# Cost at iteration 30 = 306.9711101255992
#
# Cost at iteration 31 = 306.9297922716108
#
# Cost at iteration 32 = 306.8879299357472
#
# Cost at iteration 33 = 306.8454680498431
#
# Cost at iteration 34 = 306.8023462934074
#
# Cost at iteration 35 = 306.75849644365724
#
# Cost at iteration 36 = 306.71383777062204
#
# Cost at iteration 37 = 306.6682810872276
#
# Cost at iteration 38 = 306.6217263123361
#
# Cost at iteration 39 = 306.57406192288124
#
# Cost at iteration 40 = 306.52515493607467
#
# Cost at iteration 41 = 306.4748550354613
#
# Cost at iteration 42 = 306.4229937242486
#
# Cost at iteration 43 = 306.3693799313159
#
# Cost at iteration 44 = 306.31379829920996
#
# Cost at iteration 45 = 306.2559984308361
#
# Cost at iteration 46 = 306.1956915446772
#
# Cost at iteration 47 = 306.1325417391397
#
# Cost at iteration 48 = 306.0661637014296
#
# Cost at iteration 49 = 305.99610202369576
#
# Cost at iteration 50 = 305.921820685294
#
# Cost at iteration 51 = 305.84269453752006
#
# Cost at iteration 52 = 305.7579851307877
#
# Cost at iteration 53 = 305.6668220667395
#
# Cost at iteration 54 = 305.56816321971564
#
# Cost at iteration 55 = 305.4607675802146
#
# Cost at iteration 56 = 305.3431404853516
#
# Cost at iteration 57 = 305.21347591020447
#
# Cost at iteration 58 = 305.0695793852814
#
# Cost at iteration 59 = 304.9087685810632
#
# Cost at iteration 60 = 304.7277440180277
#
# Cost at iteration 61 = 304.5224196366737
#
# Cost at iteration 62 = 304.28769909504643
#
# Cost at iteration 63 = 304.01717746831315
#
# Cost at iteration 64 = 303.70273862146576
#
# Cost at iteration 65 = 303.3340085693466
#
# Cost at iteration 66 = 302.89760525151576
#
# Cost at iteration 67 = 302.376093862308
#
# Cost at iteration 68 = 301.746519061183
#
# Cost at iteration 69 = 300.9783164286546
#
# Cost at iteration 70 = 300.03029749905664
#
# Cost at iteration 71 = 298.84625165888934
#
# Cost at iteration 72 = 297.34843906395776
#
# Cost at iteration 73 = 295.4278535885727
#
# Cost at iteration 74 = 292.92949641660203
#
# Cost at iteration 75 = 289.6299559996965
#
# Cost at iteration 76 = 285.2032783159835
#
# Cost at iteration 77 = 279.1697364660717
#
# Cost at iteration 78 = 270.8221933770758
#
# Cost at iteration 79 = 259.13192883653124
#
# Cost at iteration 80 = 242.6675317396472
#
# Cost at iteration 81 = 219.6624279317481
#
# Cost at iteration 82 = 188.6199588647968
#
# Cost at iteration 83 = 150.1982121636788
#
# Cost at iteration 84 = 110.4734565554627
#
# Cost at iteration 85 = 81.05083107447514
#
# Cost at iteration 86 = 68.23318661992211
#
# Cost at iteration 87 = 65.04755150055186
#
# Cost at iteration 88 = 63.952166591551865
#
# Cost at iteration 89 = 63.062702217379176
#
# Cost at iteration 90 = 62.209970769354236
#
# Cost at iteration 91 = 61.38442053679102
#
# Cost at iteration 92 = 60.58448844600914
#
# Cost at iteration 93 = 59.80906804925287
#
# Cost at iteration 94 = 59.057191018183616
#
# Cost at iteration 95 = 58.32800039833609
#
# Cost at iteration 96 = 57.62073778730614
#
# Cost at iteration 97 = 56.9347325642913
#
# Cost at iteration 98 = 56.26939227066978
#
# Cost at iteration 99 = 55.62419389479039
#
# Cost at iteration 100 = 54.998675906184964
#
# Cost at iteration 101 = 54.392430918740985
#
# Cost at iteration 102 = 53.80509888530444
#
# Cost at iteration 103 = 53.23636074487624
#
# Cost at iteration 104 = 52.68593245964117
#
# Cost at iteration 105 = 52.15355939313342
#
# Cost at iteration 106 = 51.63901099324919
#
# Cost at iteration 107 = 51.14207575479158
#
# Cost at iteration 108 = 50.66255644593211
#
# Cost at iteration 109 = 50.20026559148377
#
# Cost at iteration 110 = 49.7550212132456
#
# Cost at iteration 111 = 49.32664283390549
#
# Cost at iteration 112 = 48.9149477560544
#
# Cost at iteration 113 = 48.51974763174204
#
# Cost at iteration 114 = 48.14084534065207
#
# Cost at iteration 115 = 47.77803219636765
#
# Cost at iteration 116 = 47.43108550032177
#
# Cost at iteration 117 = 47.099766461893665
#
# Cost at iteration 118 = 46.78381850076854
#
# Cost at iteration 119 = 46.482965944202434
#
# Cost at iteration 120 = 46.19691312734747
#
# Cost at iteration 121 = 45.92534389945629
#
# Cost at iteration 122 = 45.66792153279049
#
# Cost at iteration 123 = 45.424289024634646
#
# Cost at iteration 124 = 45.19406977621002
#
# Cost at iteration 125 = 44.976868625750846
#
# Cost at iteration 126 = 44.772273206808265
#
# Cost at iteration 127 = 44.57985559722871
#
# Cost at iteration 128 = 44.3991742194351
#
# Cost at iteration 129 = 44.22977594880552
#
# Cost at iteration 130 = 44.071198384234265
#
# Cost at iteration 131 = 43.92297223346349
#
# Cost at iteration 132 = 43.784623765523015
#
# Cost at iteration 133 = 43.65567728359151
#
# Cost at iteration 134 = 43.535657573720485
#
# Cost at iteration 135 = 43.424092288026856
#
# Cost at iteration 136 = 43.32051422500436
#
# Cost at iteration 137 = 43.22446347434731
#
# Cost at iteration 138 = 43.13548939892228
#
# Cost at iteration 139 = 43.05315243206153
#
# Cost at iteration 140 = 42.977025673986056
#
# Cost at iteration 141 = 42.90669627671014
#
# Cost at iteration 142 = 42.841766612069506
#
# Cost at iteration 143 = 42.78185522241267
#
# Cost at iteration 144 = 42.72659755789185
#
# Cost at iteration 145 = 42.675646508109
#
# Cost at iteration 146 = 42.62867273906631
#
# Cost at iteration 147 = 42.58536484892255
#
# Cost at iteration 148 = 42.545429357972864
#
# Cost at iteration 149 = 42.5085905495794
#
# Cost at iteration 150 = 42.47459017952935
#
# Cost at iteration 151 = 42.443187071543775
#
# Cost at iteration 152 = 42.414156616471324
#
# Cost at iteration 153 = 42.38729019214589
#
# Cost at iteration 154 = 42.3623945200382
#
# Cost at iteration 155 = 42.33929097375619
#
# Cost at iteration 156 = 42.317814853213285
#
# Cost at iteration 157 = 42.29779464387652
#
# Cost at iteration 158 = 42.27910640804876
#
# Cost at iteration 159 = 42.26162795375893
#
# Cost at iteration 160 = 42.24524283845493
#
# Cost at iteration 161 = 42.22984477309793
#
# Cost at iteration 162 = 42.21530701822827
#
# Cost at iteration 163 = 42.20156259137308
#
# Cost at iteration 164 = 42.188541701742714
#
# Cost at iteration 165 = 42.17617177912245
#
# Cost at iteration 166 = 42.164387092718925
#
# Cost at iteration 167 = 42.15312818637067
#
# Cost at iteration 168 = 42.14234134781823
#
# Cost at iteration 169 = 42.13197811207807
#
# Cost at iteration 170 = 42.12199479849882
#
# Cost at iteration 171 = 42.11235208072783
#
# Cost at iteration 172 = 42.103014588543346
#
# Cost at iteration 173 = 42.0939505402975
#
# Cost at iteration 174 = 42.08513140456225
#
# Cost at iteration 175 = 42.07653158946425
#
# Cost at iteration 176 = 42.068128158130406
#
# Cost at iteration 177 = 42.059900568634035
#
# Cost at iteration 178 = 42.05183043683013
#
# Cost at iteration 179 = 42.04390247250811
#
# Cost at iteration 180 = 42.03576209827555
#
# Cost at iteration 181 = 42.02748875958851
#
# Cost at iteration 182 = 42.01934947126422
#
# Cost at iteration 183 = 42.01113653234695
#
# Cost at iteration 184 = 42.002667051984105
#
# Cost at iteration 185 = 41.99432921836694
#
# Cost at iteration 186 = 41.985996504680536
#
# Cost at iteration 187 = 41.97747910612814
#
# Cost at iteration 188 = 41.96908662539288
#
# Cost at iteration 189 = 41.96070300224107
#
# Cost at iteration 190 = 41.95224253596256
#
# Cost at iteration 191 = 41.94389728702139
#
# Cost at iteration 192 = 41.93566020126449
#
# Cost at iteration 193 = 41.927524570960315
#
# Cost at iteration 194 = 41.91948415059565
#
# Cost at iteration 195 = 41.91153313525797
#
# Cost at iteration 196 = 41.90366612797896
#
# Cost at iteration 197 = 41.8958781084714
#
# Cost at iteration 198 = 41.88816440429506
#
# Cost at iteration 199 = 41.88052066436418
#
# Cost at iteration 200 = 41.872942834612395
#
# Cost at iteration 201 = 41.86542713563582
#
# Cost at iteration 202 = 41.857970042147834
#
# Cost at iteration 203 = 41.85056826409353
#
# Cost at iteration 204 = 41.84321872928378
#
# Cost at iteration 205 = 41.83591856742093
#
# Cost at iteration 206 = 41.828665095398904
#
# Cost at iteration 207 = 41.82145580377005
#
# Cost at iteration 208 = 41.81428834428086
#
# Cost at iteration 209 = 41.80716051838654
#
# Cost at iteration 210 = 41.80007026666231
#
# Cost at iteration 211 = 41.793015659036534
#
# Cost at iteration 212 = 41.785994885776994
#
# Cost at iteration 213 = 41.779006249167644
#
# Cost at iteration 214 = 41.77204815581887
#
# Cost at iteration 215 = 41.765119109558675
#
# Cost at iteration 216 = 41.75821770485724
#
# Cost at iteration 217 = 41.75134262074126
#
# Cost at iteration 218 = 41.74449261515825
#
# Cost at iteration 219 = 41.73766651975412
#
# Cost at iteration 220 = 41.73086323503134
#
# Cost at iteration 221 = 41.724081725856706
#
# Cost at iteration 222 = 41.717321017291354
#
# Cost at iteration 223 = 41.71058019071726
#
# Cost at iteration 224 = 41.70385838023729
#
# Cost at iteration 225 = 41.697154769327355
#
# Cost at iteration 226 = 41.69046858772111
#
# Cost at iteration 227 = 41.68379910850957
#
# Cost at iteration 228 = 41.67714564543908
#
# Cost at iteration 229 = 41.67050755039287
#
# Cost at iteration 230 = 41.66388421104219
#
# Cost at iteration 231 = 41.65727504865459
#
# Cost at iteration 232 = 41.65067951604774
#
# Cost at iteration 233 = 41.64409709567808
#
# Cost at iteration 234 = 41.6375272978545
#
# Cost at iteration 235 = 41.63096965906818
#
# Cost at iteration 236 = 41.62442374043016
#
# Cost at iteration 237 = 41.61788912620905
#
# Cost at iteration 238 = 41.611365422461844
#
# Cost at iteration 239 = 41.60485225575147
#
# Cost at iteration 240 = 41.59834927194485
#
# Cost at iteration 241 = 41.59185613508615
#
# Cost at iteration 242 = 41.58537252634001
#
# Cost at iteration 243 = 41.57889814300008
#
# Cost at iteration 244 = 41.572432697558405
#
# Cost at iteration 245 = 41.5659759168318
#
# Cost at iteration 246 = 41.55952754114117
#
# Cost at iteration 247 = 41.55308732354056
#
# Cost at iteration 248 = 41.54665502909265
#
# Cost at iteration 249 = 41.540230434187556
#
# Cost at iteration 250 = 41.53381332590234
#
# Cost at iteration 251 = 41.52740350139854
#
# Cost at iteration 252 = 41.521000767355304
#
# Cost at iteration 253 = 41.514604939435976
#
# Cost at iteration 254 = 41.50821584178592
#
# Cost at iteration 255 = 41.50183330655976
#
# Cost at iteration 256 = 41.495457173476176
#
# Cost at iteration 257 = 41.4890872893985
#
# Cost at iteration 258 = 41.48272350793963
#
# Cost at iteration 259 = 41.47636568908978
#
# Cost at iteration 260 = 41.47001369886559
#
# Cost at iteration 261 = 41.4636674089794
#
# Cost at iteration 262 = 41.45732669652745
#
# Cost at iteration 263 = 41.450991443695926
#
# Cost at iteration 264 = 41.44466153748368
#
# Cost at iteration 265 = 41.438336869440754
#
# Cost at iteration 266 = 41.43201733542172
#
# Cost at iteration 267 = 41.42570283535297
#
# Cost at iteration 268 = 41.41939327301316
#
# Cost at iteration 269 = 41.41308855582603
#
# Cost at iteration 270 = 41.40678859466487
#
# Cost at iteration 271 = 41.400493303667986
#
# Cost at iteration 272 = 41.39420260006452
#
# Cost at iteration 273 = 41.38791640401001
#
# Cost at iteration 274 = 41.381634638431116
#
# Cost at iteration 275 = 41.37535722887911
#
# Cost at iteration 276 = 41.36908410339144
#
# Cost at iteration 277 = 41.362815192361026
#
# Cost at iteration 278 = 41.35655042841291
#
# Cost at iteration 279 = 41.350289746287615
#
# Cost at iteration 280 = 41.3440330827311
#
# Cost at iteration 281 = 41.33778037639078
#
# Cost at iteration 282 = 41.33153156771726
#
# Cost at iteration 283 = 41.3252865988716
#
# Cost at iteration 284 = 41.3190454136376
#
# Cost at iteration 285 = 41.31280795733902
#
# Cost at iteration 286 = 41.30657417676132
#
# Cost at iteration 287 = 41.30034402007775
#
# Cost at iteration 288 = 41.29411743677944
#
# Cost at iteration 289 = 41.28789437760941
#
# Cost at iteration 290 = 41.28167479450025
#
# Cost at iteration 291 = 41.27545864051506
#
# Cost at iteration 292 = 41.26924586979184
#
# Cost at iteration 293 = 41.26303643749077
#
# Cost at iteration 294 = 41.256830299744436
#
# Cost at iteration 295 = 41.25062741361086
#
# Cost at iteration 296 = 41.244427737028985
#
# Cost at iteration 297 = 41.23823122877665
#
# Cost at iteration 298 = 41.23203784843085
#
# Cost at iteration 299 = 41.225847556330216
#
# Cost at iteration 300 = 41.219660313539464
#
# Cost at iteration 301 = 41.21347608181588
#
# Cost at iteration 302 = 41.20729482357751
#
# Cost at iteration 303 = 41.20111650187321
#
# Cost at iteration 304 = 41.19494108035423
#
# Cost at iteration 305 = 41.18876852324742
#
# Cost at iteration 306 = 41.18259879532983
#
# Cost at iteration 307 = 41.17643186190469
#
# Cost at iteration 308 = 41.170267688778786
#
# Cost at iteration 309 = 41.16410624224095
#
# Cost at iteration 310 = 41.15794748904175
#
# Cost at iteration 311 = 41.15179139637432
#
# Cost at iteration 312 = 41.145637931856186
#
# Cost at iteration 313 = 41.13948706351203
#
# Cost at iteration 314 = 41.13333875975755
#
# Cost at iteration 315 = 41.12719298938393
#
# Cost at iteration 316 = 41.12104972154344
#
# Cost at iteration 317 = 41.114908925735534
#
# Cost at iteration 318 = 41.108770571793904
#
# Cost at iteration 319 = 41.102634629874075
#
# Cost at iteration 320 = 41.09650107044183
#
# Cost at iteration 321 = 41.090369864262016
#
# Cost at iteration 322 = 41.08424098238825
#
# Cost at iteration 323 = 41.078114396152884
#
# Cost at iteration 324 = 41.07199007715764
#
# Cost at iteration 325 = 41.065867997264874
#
# Cost at iteration 326 = 41.05974812858894
#
# Cost at iteration 327 = 41.05363044348842
#
# Cost at iteration 328 = 41.047514914558434
#
# Cost at iteration 329 = 41.041401514623644
#
# Cost at iteration 330 = 41.03529021673133
#
# Cost at iteration 331 = 41.02918099414507
#
# Cost at iteration 332 = 41.02307382033861
#
# Cost at iteration 333 = 41.01696866899014
#
# Cost at iteration 334 = 41.01086551397679
#
# Cost at iteration 335 = 41.00476432936947
#
# Cost at iteration 336 = 40.99866508942796
#
# Cost at iteration 337 = 40.99256776859622
#
# Cost at iteration 338 = 40.986472341498015
#
# Cost at iteration 339 = 40.98037878293267
#
# Cost at iteration 340 = 40.97428706787112
#
# Cost at iteration 341 = 40.96819717145213
#
# Cost at iteration 342 = 40.96210906897873
#
# Cost at iteration 343 = 40.956022735914694
#
# Cost at iteration 344 = 40.9499381478815
#
# Cost at iteration 345 = 40.94385528065507
#
# Cost at iteration 346 = 40.937774110163
#
# Cost at iteration 347 = 40.93169461248164
#
# Cost at iteration 348 = 40.925616763833595
#
# Cost at iteration 349 = 40.919540540585096
#
# Cost at iteration 350 = 40.91346591924374
#
# Cost at iteration 351 = 40.90739287645608
#
# Cost at iteration 352 = 40.90132138900558
#
# Cost at iteration 353 = 40.8952514338105
#
# Cost at iteration 354 = 40.889182987921984
#
# Cost at iteration 355 = 40.8831160285221
#
# Cost at iteration 356 = 40.87705053292219
#
# Cost at iteration 357 = 40.87098647856109
#
# Cost at iteration 358 = 40.86492384300353
#
# Cost at iteration 359 = 40.85886260393863
#
# Cost at iteration 360 = 40.8528027391784
#
# Cost at iteration 361 = 40.846744226656355
#
# Cost at iteration 362 = 40.840687044426126
#
# Cost at iteration 363 = 40.834631170660266
#
# Cost at iteration 364 = 40.82857658364898
#
# Cost at iteration 365 = 40.822523261798956
#
# Cost at iteration 366 = 40.81647118363228
#
# Cost at iteration 367 = 40.81042032778533
#
# Cost at iteration 368 = 40.80437067300778
#
# Cost at iteration 369 = 40.79832219816162
#
# Cost at iteration 370 = 40.792274882220234
#
# Cost at iteration 371 = 40.786228704267465
#
# Cost at iteration 372 = 40.7801836434968
#
# Cost at iteration 373 = 40.77413967921052
#
# Cost at iteration 374 = 40.76809679081894
#
# Cost at iteration 375 = 40.76205495783959
#
# Cost at iteration 376 = 40.75601415989656
#
# Cost at iteration 377 = 40.749974376719784
#
# Cost at iteration 378 = 40.74393558814433
#
# Cost at iteration 379 = 40.737897774109776
#
# Cost at iteration 380 = 40.73186091465965
#
# Cost at iteration 381 = 40.72582498994072
#
# Cost at iteration 382 = 40.71978998020252
#
# Cost at iteration 383 = 40.713755865796756
#
# Cost at iteration 384 = 40.70772262717677
#
# Cost at iteration 385 = 40.70169024489706
#
# Cost at iteration 386 = 40.69565869961273
#
# Cost at iteration 387 = 40.68962797207908
#
# Cost at iteration 388 = 40.6835980431511
#
# Cost at iteration 389 = 40.67756127828578
#
# Cost at iteration 390 = 40.67149641869748
#
# Cost at iteration 391 = 40.66543198154352
#
# Cost at iteration 392 = 40.65936799326999
#
# Cost at iteration 393 = 40.65330444749902
#
# Cost at iteration 394 = 40.64724133553804
#
# Cost at iteration 395 = 40.641178648080675
#
# Cost at iteration 396 = 40.635116375333304
#
# Cost at iteration 397 = 40.629054507054285
#
# Cost at iteration 398 = 40.62299303258649
#
# Cost at iteration 399 = 40.616931940887724
#
# Cost at iteration 400 = 40.61087122055928
#
# Cost at iteration 401 = 40.60481085987285
#
# Cost at iteration 402 = 40.59875084679573
#
# Cost at iteration 403 = 40.59269116901467
#
# Cost at iteration 404 = 40.58663181395815
#
# Cost at iteration 405 = 40.58057276881739
#
# Cost at iteration 406 = 40.57451410317499
#
# Cost at iteration 407 = 40.568455737591236
#
# Cost at iteration 408 = 40.56239764278056
#
# Cost at iteration 409 = 40.55633980510788
#
# Cost at iteration 410 = 40.5502822108285
#
# Cost at iteration 411 = 40.54422484606571
#
# Cost at iteration 412 = 40.538167696822576
#
# Cost at iteration 413 = 40.53211074899462
#
# Cost at iteration 414 = 40.52605398838165
#
# Cost at iteration 415 = 40.51999740069908
#
# Cost at iteration 416 = 40.51394097158841
#
# Cost at iteration 417 = 40.507884686627186
#
# Cost at iteration 418 = 40.50182853133823
#
# Cost at iteration 419 = 40.495772491198416
#
# Cost at iteration 420 = 40.489716551646865
#
# Cost at iteration 421 = 40.48366069809267
#
# Cost at iteration 422 = 40.477604915922086
#
# Cost at iteration 423 = 40.471549190505385
#
# Cost at iteration 424 = 40.46549350720318
#
# Cost at iteration 425 = 40.45943785137239
#
# Cost at iteration 426 = 40.453382208372
#
# Cost at iteration 427 = 40.44732656356815
#
# Cost at iteration 428 = 40.44127090233922
#
# Cost at iteration 429 = 40.43521521008042
#
# Cost at iteration 430 = 40.42915947220822
#
# Cost at iteration 431 = 40.423103674164295
#
# Cost at iteration 432 = 40.41704780141955
#
# Cost at iteration 433 = 40.410991839477596
#
# Cost at iteration 434 = 40.404935773878194
#
# Cost at iteration 435 = 40.398879590200394
#
# Cost at iteration 436 = 40.39282327406551
#
# Cost at iteration 437 = 40.386766811139985
#
# Cost at iteration 438 = 40.380710187137865
#
# Cost at iteration 439 = 40.37465338782339
#
# Cost at iteration 440 = 40.36859639901324
#
# Cost at iteration 441 = 40.36253920657869
#
# Cost at iteration 442 = 40.356481796447625
#
# Cost at iteration 443 = 40.3504241546065
#
# Cost at iteration 444 = 40.344366267102046
#
# Cost at iteration 445 = 40.33830812004296
#
# Cost at iteration 446 = 40.332249699601505
#
# Cost at iteration 447 = 40.326190992014915
#
# Cost at iteration 448 = 40.32013198358682
#
# Cost at iteration 449 = 40.31407266068852
#
# Cost at iteration 450 = 40.308013009760145
#
# Cost at iteration 451 = 40.30195301731188
#
# Cost at iteration 452 = 40.29589266992493
#
# Cost at iteration 453 = 40.28983195425257
#
# Cost at iteration 454 = 40.28377085702104
#
# Cost at iteration 455 = 40.27770936503044
#
# Cost at iteration 456 = 40.27164746515554
#
# Cost at iteration 457 = 40.26558514434652
#
# Cost at iteration 458 = 40.25952238962976
#
# Cost at iteration 459 = 40.253459188108394
#
# Cost at iteration 460 = 40.24739552696303
#
# Cost at iteration 461 = 40.241331393452306
#
# Cost at iteration 462 = 40.23526677491344
#
# Cost at iteration 463 = 40.22920165876276
#
# Cost at iteration 464 = 40.22313603249615
#
# Cost at iteration 465 = 40.21706988368953
#
# Cost at iteration 466 = 40.21100319999932
#
# Cost at iteration 467 = 40.204935969162705
#
# Cost at iteration 468 = 40.198868178998175
#
# Cost at iteration 469 = 40.192799817405735
#
# Cost at iteration 470 = 40.18673087236731
#
# Cost at iteration 471 = 40.180640409302164
#
# Cost at iteration 472 = 40.17452824925364
#
# Cost at iteration 473 = 40.16841517498681
#
# Cost at iteration 474 = 40.16230120156779
#
# Cost at iteration 475 = 40.156186325715616
#
# Cost at iteration 476 = 40.15007054333549
#
# Cost at iteration 477 = 40.14395384989114
#
# Cost at iteration 478 = 40.13783624044516
#
# Cost at iteration 479 = 40.13171770969096
#
# Cost at iteration 480 = 40.12559825198255
#
# Cost at iteration 481 = 40.119477861362434
#
# Cost at iteration 482 = 40.11335653158768
#
# Cost at iteration 483 = 40.107234256154385
#
# Cost at iteration 484 = 40.101111028320396
#
# Cost at iteration 485 = 40.094986841126854
#
# Cost at iteration 486 = 40.08886168741802
#
# Cost at iteration 487 = 40.082684963264064
#
# Cost at iteration 488 = 40.07650192246499
#
# Cost at iteration 489 = 40.070317635795185
#
# Cost at iteration 490 = 40.06413210286234
#
# Cost at iteration 491 = 40.05794532007826
#
# Cost at iteration 492 = 40.05175728339196
#
# Cost at iteration 493 = 40.045567988352445
#
# Cost at iteration 494 = 40.03937743014175
#
# Cost at iteration 495 = 40.03318560360533
#
# Cost at iteration 496 = 40.02699250328076
#
# Cost at iteration 497 = 40.020798123424264
#
# Cost at iteration 498 = 40.014602458035796
#
# Cost at iteration 499 = 40.008405500882226
#
# Cost at iteration 500 = 40.00220737609791
#
# Cost at iteration 501 = 39.99600795970022
#
# Cost at iteration 502 = 39.98980723194675
#
# Cost at iteration 503 = 39.98360518585762
#
# Cost at iteration 504 = 39.97740181432691
#
# Cost at iteration 505 = 39.97119711012683
#
# Cost at iteration 506 = 39.96499106592213
#
# Cost at iteration 507 = 39.95878367428343
#
# Cost at iteration 508 = 39.952574927699786
#
# Cost at iteration 509 = 39.94636481859031
#
# Cost at iteration 510 = 39.940153339315096
#
# Cost at iteration 511 = 39.933940482185335
#
# Cost at iteration 512 = 39.927726239472825
#
# Cost at iteration 513 = 39.92151060341872
#
# Cost at iteration 514 = 39.915293566241836
#
# Cost at iteration 515 = 39.90907512014632
#
# Cost at iteration 516 = 39.902855257328746
#
# Cost at iteration 517 = 39.896633969984805
#
# Cost at iteration 518 = 39.89041125031559
#
# Cost at iteration 519 = 39.88418709053325
#
# Cost at iteration 520 = 39.87796148286651
#
# Cost at iteration 521 = 39.871734419565676
#
# Cost at iteration 522 = 39.86550589290722
#
# Cost at iteration 523 = 39.85927589519831
#
# Cost at iteration 524 = 39.8530444187807
#
# Cost at iteration 525 = 39.84681145603468
#
# Cost at iteration 526 = 39.84057699938246
#
# Cost at iteration 527 = 39.834341041291566
#
# Cost at iteration 528 = 39.82810357427785
#
# Cost at iteration 529 = 39.8218645909083
#
# Cost at iteration 530 = 39.81562408380375
#
# Cost at iteration 531 = 39.809382045641314
#
# Cost at iteration 532 = 39.80313846915672
#
# Cost at iteration 533 = 39.796893347146366
#
# Cost at iteration 534 = 39.79064667246938
#
# Cost at iteration 535 = 39.78439843804945
#
# Cost at iteration 536 = 39.77814863687652
#
# Cost at iteration 537 = 39.771897262008416
#
# Cost at iteration 538 = 39.765644306572305
#
# Cost at iteration 539 = 39.75938976376609
#
# Cost at iteration 540 = 39.753133626859686
#
# Cost at iteration 541 = 39.74687588919622
#
# Cost at iteration 542 = 39.74061654419311
#
# Cost at iteration 543 = 39.73435558534314
#
# Cost at iteration 544 = 39.72809300621537
#
# Cost at iteration 545 = 39.72182880045599
#
# Cost at iteration 546 = 39.71556296178923
#
# Cost at iteration 547 = 39.70929548401802
#
# Cost at iteration 548 = 39.703026361024776
#
# Cost at iteration 549 = 39.69675558677194
#
# Cost at iteration 550 = 39.69048315530273
#
# Cost at iteration 551 = 39.68417439687313
#
# Cost at iteration 552 = 39.677845906619915
#
# Cost at iteration 553 = 39.67151554119484
#
# Cost at iteration 554 = 39.66518329505512
#
# Cost at iteration 555 = 39.65884916225765
#
# Cost at iteration 556 = 39.65251313694987
#
# Cost at iteration 557 = 39.646175213355434
#
# Cost at iteration 558 = 39.6398353857753
#
# Cost at iteration 559 = 39.63349364858834
#
# Cost at iteration 560 = 39.62714999625199
#
# Cost at iteration 561 = 39.6208044233028
#
# Cost at iteration 562 = 39.614456924357164
#
# Cost at iteration 563 = 39.60810760632345
#
# Cost at iteration 564 = 39.601756371467154
#
# Cost at iteration 565 = 39.595403195077914
#
# Cost at iteration 566 = 39.589048072101775
#
# Cost at iteration 567 = 39.582690997567326
#
# Cost at iteration 568 = 39.57633196658544
#
# Cost at iteration 569 = 39.56997097434973
#
# Cost at iteration 570 = 39.563608016136854
#
# Cost at iteration 571 = 39.55724308730697
#
# Cost at iteration 572 = 39.55087618330411
#
# Cost at iteration 573 = 39.54450729965636
#
# Cost at iteration 574 = 39.53813643197623
#
# Cost at iteration 575 = 39.531763575960895
#
# Cost at iteration 576 = 39.52538872739243
#
# Cost at iteration 577 = 39.51901188213805
#
# Cost at iteration 578 = 39.512633036150255
#
# Cost at iteration 579 = 39.50625218546697
#
# Cost at iteration 580 = 39.49986932621176
#
# Cost at iteration 581 = 39.49348445459392
#
# Cost at iteration 582 = 39.48709756690859
#
# Cost at iteration 583 = 39.48070865953681
#
# Cost at iteration 584 = 39.47431772894565
#
# Cost at iteration 585 = 39.46792477168822
#
# Cost at iteration 586 = 39.4615297844037
#
# Cost at iteration 587 = 39.455132763817424
#
# Cost at iteration 588 = 39.448733706740825
#
# Cost at iteration 589 = 39.44233261007148
#
# Cost at iteration 590 = 39.435929470793056
#
# Cost at iteration 591 = 39.42952428597527
#
# Cost at iteration 592 = 39.423117052773925
#
# Cost at iteration 593 = 39.416707768430776
#
# Cost at iteration 594 = 39.41029643027346
#
# Cost at iteration 595 = 39.40388303571553
#
# Cost at iteration 596 = 39.39746758225625
#
# Cost at iteration 597 = 39.391050067480506
#
# Cost at iteration 598 = 39.38463048905881
#
# Cost at iteration 599 = 39.37820884474707
#
# Cost at iteration 600 = 39.371785132386506
#
# Cost at iteration 601 = 39.36535934990355
#
# Cost at iteration 602 = 39.358931495309605
#
# Cost at iteration 603 = 39.35250156670104
#
# Cost at iteration 604 = 39.34606956225892
#
# Cost at iteration 605 = 39.33963548024887
#
# Cost at iteration 606 = 39.333199319020885
#
# Cost at iteration 607 = 39.32676107700921
#
# Cost at iteration 608 = 39.32032075273207
#
# Cost at iteration 609 = 39.31387834479152
#
# Cost at iteration 610 = 39.307433851873235
#
# Cost at iteration 611 = 39.300987272746255
#
# Cost at iteration 612 = 39.29453860626283
#
# Cost at iteration 613 = 39.28808785135815
#
# Cost at iteration 614 = 39.28163500705014
#
# Cost at iteration 615 = 39.27518007243915
#
# Cost at iteration 616 = 39.2687230467078
#
# Cost at iteration 617 = 39.262263929120685
#
# Cost at iteration 618 = 39.25580271902407
#
# Cost at iteration 619 = 39.24933941584569
#
# Cost at iteration 620 = 39.24287401909442
#
# Cost at iteration 621 = 39.236406528360035
#
# Cost at iteration 622 = 39.22993694331288
#
# Cost at iteration 623 = 39.22346526370359
#
# Cost at iteration 624 = 39.2169914893628
#
# Cost at iteration 625 = 39.2105156202008
#
# Cost at iteration 626 = 39.20403765620728
#
# Cost at iteration 627 = 39.1975575974509
#
# Cost at iteration 628 = 39.1910754440791
#
# Cost at iteration 629 = 39.1845911963176
#
# Cost at iteration 630 = 39.1781048544702
#
# Cost at iteration 631 = 39.171616418918354
#
# Cost at iteration 632 = 39.165125890120805
#
# Cost at iteration 633 = 39.158633268613286
#
# Cost at iteration 634 = 39.15213855500805
#
# Cost at iteration 635 = 39.14564174999356
#
# Cost at iteration 636 = 39.13914285433409
#
# Cost at iteration 637 = 39.13264186886935
#
# Cost at iteration 638 = 39.12613879451401
#
# Cost at iteration 639 = 39.11963363225739
#
# Cost at iteration 640 = 39.113126383162985
#
# Cost at iteration 641 = 39.10661704836807
#
# Cost at iteration 642 = 39.100105629083274
#
# Cost at iteration 643 = 39.09359212659212
#
# Cost at iteration 644 = 39.087076542250585
#
# Cost at iteration 645 = 39.08055887748669
#
# Cost at iteration 646 = 39.074039133800035
#
# Cost at iteration 647 = 39.06751731276128
#
# Cost at iteration 648 = 39.06099341601176
#
# Cost at iteration 649 = 39.05446744526293
#
# Cost at iteration 650 = 39.04793940229593
#
# Cost at iteration 651 = 39.0414092889611
#
# Cost at iteration 652 = 39.03487710717743
#
# Cost at iteration 653 = 39.0283428589321
#
# Cost at iteration 654 = 39.021806546279954
#
# Cost at iteration 655 = 39.01526817134301
#
# Cost at iteration 656 = 39.00872773630986
#
# Cost at iteration 657 = 39.0021852434352
#
# Cost at iteration 658 = 38.99564069503928
#
# Cost at iteration 659 = 38.98909409350735
#
# Cost at iteration 660 = 38.982545441289076
#
# Cost at iteration 661 = 38.97599474089804
#
# Cost at iteration 662 = 38.969441994911094
#
# Cost at iteration 663 = 38.96288720596786
#
# Cost at iteration 664 = 38.956330376770104
#
# Cost at iteration 665 = 38.94977151008113
#
# Cost at iteration 666 = 38.94321060872521
#
# Cost at iteration 667 = 38.936647675587004
#
# Cost at iteration 668 = 38.93008271361088
#
# Cost at iteration 669 = 38.92351572580033
#
# Cost at iteration 670 = 38.91694671521739
#
# Cost at iteration 671 = 38.91037568498191
#
# Cost at iteration 672 = 38.90380263827096
#
# Cost at iteration 673 = 38.89722757831824
#
# Cost at iteration 674 = 38.89065050841333
#
# Cost at iteration 675 = 38.884071431901056
#
# Cost at iteration 676 = 38.87749035218089
#
# Cost at iteration 677 = 38.87090727270616
#
# Cost at iteration 678 = 38.864322196983466
#
# Cost at iteration 679 = 38.85773512857191
#
# Cost at iteration 680 = 38.85114607108247
#
# Cost at iteration 681 = 38.84455502817724
#
# Cost at iteration 682 = 38.83796200356876
#
# Cost at iteration 683 = 38.83136700101928
#
# Cost at iteration 684 = 38.82477002434002
#
# Cost at iteration 685 = 38.81817107739047
#
# Cost at iteration 686 = 38.811570164077615
#
# Cost at iteration 687 = 38.80496728835523
#
# Cost at iteration 688 = 38.79836245422311
#
# Cost at iteration 689 = 38.791755665726285
#
# Cost at iteration 690 = 38.78514692695428
#
# Cost at iteration 691 = 38.77853624204041
#
# Cost at iteration 692 = 38.77192361516084
#
# Cost at iteration 693 = 38.76530905053393
#
# Cost at iteration 694 = 38.75869255241942
#
# Cost at iteration 695 = 38.75207412511761
#
# Cost at iteration 696 = 38.74545377296855
#
# Cost at iteration 697 = 38.73883150035125
#
# Cost at iteration 698 = 38.732207311682885
#
# Cost at iteration 699 = 38.725581211417875
#
# Cost at iteration 700 = 38.71895320404719
#
# Cost at iteration 701 = 38.7123232940974
#
# Cost at iteration 702 = 38.70569148612991
#
# Cost at iteration 703 = 38.69905778474004
#
# Cost at iteration 704 = 38.692422194556265
#
# Cost at iteration 705 = 38.685784720239255
#
# Cost at iteration 706 = 38.67914536648107
#
# Cost at iteration 707 = 38.672504138004285
#
# Cost at iteration 708 = 38.66586103956108
#
# Cost at iteration 709 = 38.6592160759324
#
# Cost at iteration 710 = 38.65256925192701
#
# Cost at iteration 711 = 38.64592057238069
#
# Cost at iteration 712 = 38.63927004215521
#
# Cost at iteration 713 = 38.63261766613755
#
# Cost at iteration 714 = 38.62596344923892
#
# Cost at iteration 715 = 38.61930739639382
#
# Cost at iteration 716 = 38.612649512559216
#
# Cost at iteration 717 = 38.605989802713516
#
# Cost at iteration 718 = 38.59932827185569
#
# Cost at iteration 719 = 38.59266492500432
#
# Cost at iteration 720 = 38.58599976719667
#
# Cost at iteration 721 = 38.57933280348772
#
# Cost at iteration 722 = 38.572664038949235
#
# Cost at iteration 723 = 38.56599347866881
#
# Cost at iteration 724 = 38.55932112774888
#
# Cost at iteration 725 = 38.552646991305814
#
# Cost at iteration 726 = 38.54597107446888
#
# Cost at iteration 727 = 38.53929338237936
#
# Cost at iteration 728 = 38.53261392018947
#
# Cost at iteration 729 = 38.52593269306144
#
# Cost at iteration 730 = 38.51924970616654
#
# Cost at iteration 731 = 38.51256496468408
#
# Cost at iteration 732 = 38.505878473800394
#
# Cost at iteration 733 = 38.49919023870786
#
# Cost at iteration 734 = 38.49250026460394
#
# Cost at iteration 735 = 38.48580855669011
#
# Cost at iteration 736 = 38.47911512017092
#
# Cost at iteration 737 = 38.47241996025292
#
# Cost at iteration 738 = 38.46572308214373
#
# Cost at iteration 739 = 38.45902449105095
#
# Cost at iteration 740 = 38.45232419218119
#
# Cost at iteration 741 = 38.44562219073902
#
# Cost at iteration 742 = 38.438918491926
#
# Cost at iteration 743 = 38.432213100939585
#
# Cost at iteration 744 = 38.42550602297215
#
# Cost at iteration 745 = 38.418797263209946
#
# Cost at iteration 746 = 38.41208682683207
#
# Cost at iteration 747 = 38.405374719009444
#
# Cost at iteration 748 = 38.39866094490374
#
# Cost at iteration 749 = 38.391945509666385
#
# Cost at iteration 750 = 38.38522841843753
#
# Cost at iteration 751 = 38.378509676344976
#
# Cost at iteration 752 = 38.37178928850316
#
# Cost at iteration 753 = 38.36506726001208
#
# Cost at iteration 754 = 38.35834359595631
#
# Cost at iteration 755 = 38.35161830140393
#
# Cost at iteration 756 = 38.34489138140541
#
# Cost at iteration 757 = 38.338162840992744
#
# Cost at iteration 758 = 38.33143268517818
#
# Cost at iteration 759 = 38.32470091895335
#
# Cost at iteration 760 = 38.317967547288156
#
# Cost at iteration 761 = 38.311232575129736
#
# Cost at iteration 762 = 38.3044960074014
#
# Cost at iteration 763 = 38.297757849001606
#
# Cost at iteration 764 = 38.291018104802895
#
# Cost at iteration 765 = 38.28427677965089
#
# Cost at iteration 766 = 38.27753387836321
#
# Cost at iteration 767 = 38.27078940572843
#
# Cost at iteration 768 = 38.26404336650506
#
# Cost at iteration 769 = 38.257295765420494
#
# Cost at iteration 770 = 38.25054660716999
#
# Cost at iteration 771 = 38.24379589641558
#
# Cost at iteration 772 = 38.23704363778507
#
# Cost at iteration 773 = 38.230289835871055
#
# Cost at iteration 774 = 38.223534495229764
#
# Cost at iteration 775 = 38.21677762038016
#
# Cost at iteration 776 = 38.2100192158028
#
# Cost at iteration 777 = 38.20325928593891
#
# Cost at iteration 778 = 38.19649783518928
#
# Cost at iteration 779 = 38.18973486791327
#
# Cost at iteration 780 = 38.18297038842783
#
# Cost at iteration 781 = 38.17620440100642
#
# Cost at iteration 782 = 38.16943690987805
#
# Cost at iteration 783 = 38.16266791922624
#
# Cost at iteration 784 = 38.155897433188
#
# Cost at iteration 785 = 38.14912545585291
#
# Cost at iteration 786 = 38.142351991262
#
# Cost at iteration 787 = 38.13557704340687
#
# Cost at iteration 788 = 38.128800616228624
#
# Cost at iteration 789 = 38.12202271361691
#
# Cost at iteration 790 = 38.11524333940892
#
# Cost at iteration 791 = 38.10846249738845
#
# Cost at iteration 792 = 38.10168019128493
#
# Cost at iteration 793 = 38.094896424772344
#
# Cost at iteration 794 = 38.088111201468436
#
# Cost at iteration 795 = 38.081324524933635
#
# Cost at iteration 796 = 38.07453639867013
#
# Cost at iteration 797 = 38.06774682612093
#
# Cost at iteration 798 = 38.06095581066893
#
# Cost at iteration 799 = 38.054163355635936
#
# Cost at iteration 800 = 38.047369464281765
#
# Cost at iteration 801 = 38.040574139803354
#
# Cost at iteration 802 = 38.03377738533374
#
# Cost at iteration 803 = 38.02697920394124
#
# Cost at iteration 804 = 38.02017959862852
#
# Cost at iteration 805 = 38.01337857233166
#
# Cost at iteration 806 = 38.00657612791931
#
# Cost at iteration 807 = 37.99977226819177
#
# Cost at iteration 808 = 37.99296699588013
#
# Cost at iteration 809 = 37.986160313645385
#
# Cost at iteration 810 = 37.97935222407755
#
# Cost at iteration 811 = 37.972542729694865
#
# Cost at iteration 812 = 37.96573183294288
#
# Cost at iteration 813 = 37.95891953619364
#
# Cost at iteration 814 = 37.952105841744846
#
# Cost at iteration 815 = 37.945290751819016
#
# Cost at iteration 816 = 37.93847426856271
#
# Cost at iteration 817 = 37.93165639404565
#
# Cost at iteration 818 = 37.92483713025998
#
# Cost at iteration 819 = 37.91801647911941
#
# Cost at iteration 820 = 37.91119444245852
#
# Cost at iteration 821 = 37.90437102203188
#
# Cost at iteration 822 = 37.897546219513345
#
# Cost at iteration 823 = 37.89072003649529
#
# Cost at iteration 824 = 37.88389247448782
#
# Cost at iteration 825 = 37.87706353491808
#
# Cost at iteration 826 = 37.87023321912951
#
# Cost at iteration 827 = 37.8634015283811
#
# Cost at iteration 828 = 37.85656846384666
#
# Cost at iteration 829 = 37.849734026614215
#
# Cost at iteration 830 = 37.842898217685196
#
# Cost at iteration 831 = 37.83606103797378
#
# Cost at iteration 832 = 37.82922248830629
#
# Cost at iteration 833 = 37.82238256942046
#
# Cost at iteration 834 = 37.81554128196479
#
# Cost at iteration 835 = 37.80869862649793
#
# Cost at iteration 836 = 37.80185460348799
#
# Cost at iteration 837 = 37.79500921331201
#
# Cost at iteration 838 = 37.78816245625525
#
# Cost at iteration 839 = 37.781314332510675
#
# Cost at iteration 840 = 37.77446484217829
#
# Cost at iteration 841 = 37.767613985264596
#
# Cost at iteration 842 = 37.760761761682005
#
# Cost at iteration 843 = 37.753908171248334
#
# Cost at iteration 844 = 37.74705321368617
#
# Cost at iteration 845 = 37.740196888622414
#
# Cost at iteration 846 = 37.73333919558768
#
# Cost at iteration 847 = 37.726480134015894
#
# Cost at iteration 848 = 37.71961970324366
#
# Cost at iteration 849 = 37.71275790250984
#
# Cost at iteration 850 = 37.7058947309551
#
# Cost at iteration 851 = 37.69903018762136
#
# Cost at iteration 852 = 37.69216427145144
#
# Cost at iteration 853 = 37.68529698128852
#
# Cost at iteration 854 = 37.67842831587577
#
# Cost at iteration 855 = 37.67155827385589
#
# Cost at iteration 856 = 37.664686853770746
#
# Cost at iteration 857 = 37.657814054060914
#
# Cost at iteration 858 = 37.650939873065354
#
# Cost at iteration 859 = 37.64406430902102
#
# Cost at iteration 860 = 37.63718736006245
#
# Cost at iteration 861 = 37.63030902422147
#
# Cost at iteration 862 = 37.62342929942687
#
# Cost at iteration 863 = 37.616548183504015
#
# Cost at iteration 864 = 37.60966567417462
#
# Cost at iteration 865 = 37.60278176905635
#
# Cost at iteration 866 = 37.59589646566259
#
# Cost at iteration 867 = 37.589009761402195
#
# Cost at iteration 868 = 37.582121653579144
#
# Cost at iteration 869 = 37.57523213939239
#
# Cost at iteration 870 = 37.568341215935526
#
# Cost at iteration 871 = 37.56144888019663
#
# Cost at iteration 872 = 37.55455512905799
#
# Cost at iteration 873 = 37.547659959295956
#
# Cost at iteration 874 = 37.54076336758073
#
# Cost at iteration 875 = 37.5338653504762
#
# Cost at iteration 876 = 37.52696590443969
#
# Cost at iteration 877 = 37.520065025821985
#
# Cost at iteration 878 = 37.51316271086702
#
# Cost at iteration 879 = 37.50625895571181
#
# Cost at iteration 880 = 37.49935375638637
#
# Cost at iteration 881 = 37.49244710881359
#
# Cost at iteration 882 = 37.48553900880909
#
# Cost at iteration 883 = 37.47862945208126
#
# Cost at iteration 884 = 37.47171843423106
#
# Cost at iteration 885 = 37.464805950752044
#
# Cost at iteration 886 = 37.457891997030316
#
# Cost at iteration 887 = 37.450975856205524
#
# Cost at iteration 888 = 37.444055383480574
#
# Cost at iteration 889 = 37.43713341678979
#
# Cost at iteration 890 = 37.43020995131124
#
# Cost at iteration 891 = 37.423284981844574
#
# Cost at iteration 892 = 37.416358503216884
#
# Cost at iteration 893 = 37.4094305100781
#
# Cost at iteration 894 = 37.40250099700494
#
# Cost at iteration 895 = 37.39556995844827
#
# Cost at iteration 896 = 37.38863738876023
#
# Cost at iteration 897 = 37.38170328218059
#
# Cost at iteration 898 = 37.37476763284403
#
# Cost at iteration 899 = 37.36783043477663
#
# Cost at iteration 900 = 37.360891681897954
#
# Cost at iteration 901 = 37.353951368020226
#
# Cost at iteration 902 = 37.3470094868491
#
# Cost at iteration 903 = 37.34006603198353
#
# Cost at iteration 904 = 37.33312099691609
#
# Cost at iteration 905 = 37.32617437503319
#
# Cost at iteration 906 = 37.319226057870274
#
# Cost at iteration 907 = 37.312274657153786
#
# Cost at iteration 908 = 37.30532163842398
#
# Cost at iteration 909 = 37.29836699564595
#
# Cost at iteration 910 = 37.291410721114076
#
# Cost at iteration 911 = 37.284452807868405
#
# Cost at iteration 912 = 37.277493248370185
#
# Cost at iteration 913 = 37.270532035232655
#
# Cost at iteration 914 = 37.26356916081772
#
# Cost at iteration 915 = 37.25660461746108
#
# Cost at iteration 916 = 37.24963839734753
#
# Cost at iteration 917 = 37.24267049258174
#
# Cost at iteration 918 = 37.23570089514927
#
# Cost at iteration 919 = 37.22872959693947
#
# Cost at iteration 920 = 37.22175658973335
#
# Cost at iteration 921 = 37.214781865211215
#
# Cost at iteration 922 = 37.20780541494912
#
# Cost at iteration 923 = 37.2008272304217
#
# Cost at iteration 924 = 37.193847303001284
#
# Cost at iteration 925 = 37.18686562395918
#
# Cost at iteration 926 = 37.17988218446566
#
# Cost at iteration 927 = 37.17289697559076
#
# Cost at iteration 928 = 37.16590998830452
#
# Cost at iteration 929 = 37.15892121347764
#
# Cost at iteration 930 = 37.151930641881805
#
# Cost at iteration 931 = 37.14493826419028
#
# Cost at iteration 932 = 37.137944070978314
#
# Cost at iteration 933 = 37.130948052723646
#
# Cost at iteration 934 = 37.12395019980701
#
# Cost at iteration 935 = 37.11695050251258
#
# Cost at iteration 936 = 37.10994895102853
#
# Cost at iteration 937 = 37.10294553544743
#
# Cost at iteration 938 = 37.09594024576686
#
# Cost at iteration 939 = 37.088933071889834
#
# Cost at iteration 940 = 37.08192400362533
#
# Cost at iteration 941 = 37.074913030688855
#
# Cost at iteration 942 = 37.06790014270289
#
# Cost at iteration 943 = 37.060885329197475
#
# Cost at iteration 944 = 37.0538685796107
#
# Cost at iteration 945 = 37.04684988328927
#
# Cost at iteration 946 = 37.039829229489044
#
# Cost at iteration 947 = 37.03280660737554
#
# Cost at iteration 948 = 37.025782006024556
#
# Cost at iteration 949 = 37.01875541442267
#
# Cost at iteration 950 = 37.0117268214678
#
# Cost at iteration 951 = 37.00469621596984
#
# Cost at iteration 952 = 36.99766358665111
#
# Cost at iteration 953 = 36.99062892214705
#
# Cost at iteration 954 = 36.98359221100676
#
# Cost at iteration 955 = 36.976553441693504
#
# Cost at iteration 956 = 36.96951260258542
#
# Cost at iteration 957 = 36.962469681976046
#
# Cost at iteration 958 = 36.95542466807493
#
# Cost at iteration 959 = 36.948377549008235
#
# Cost at iteration 960 = 36.941328312819294
#
# Cost at iteration 961 = 36.9342769474693
#
# Cost at iteration 962 = 36.927223440837864
#
# Cost at iteration 963 = 36.920167780723624
#
# Cost at iteration 964 = 36.91310995484488
#
# Cost at iteration 965 = 36.906049950840206
#
# Cost at iteration 966 = 36.89898775626909
#
# Cost at iteration 967 = 36.89192335861254
#
# Cost at iteration 968 = 36.88485674527368
#
# Cost at iteration 969 = 36.87778790357848
#
# Cost at iteration 970 = 36.87071682077626
#
# Cost at iteration 971 = 36.863643484040416
#
# Cost at iteration 972 = 36.85656788046903
#
# Cost at iteration 973 = 36.84948999708548
#
# Cost at iteration 974 = 36.84240982083914
#
# Cost at iteration 975 = 36.83532733860595
#
# Cost at iteration 976 = 36.82824253718911
#
# Cost at iteration 977 = 36.82115540331971
#
# Cost at iteration 978 = 36.81406592365734
#
# Cost at iteration 979 = 36.80697408479078
#
# Cost at iteration 980 = 36.799879873238645
#
# Cost at iteration 981 = 36.79278327544998
#
# Cost at iteration 982 = 36.78568427780496
#
# Cost at iteration 983 = 36.778582866615494
#
# Cost at iteration 984 = 36.77147902812594
#
# Cost at iteration 985 = 36.76437274851363
#
# Cost at iteration 986 = 36.75726401388966
#
# Cost at iteration 987 = 36.75015281029942
#
# Cost at iteration 988 = 36.74303912372329
#
# Cost at iteration 989 = 36.73592294007731
#
# Cost at iteration 990 = 36.72880424521372
#
# Cost at iteration 991 = 36.72168302492174
#
# Cost at iteration 992 = 36.71455926492809
#
# Cost at iteration 993 = 36.70743295089771
#
# Cost at iteration 994 = 36.70030406843438
#
# Cost at iteration 995 = 36.693172603081294
#
# Cost at iteration 996 = 36.68603854032178
#
# Cost at iteration 997 = 36.67890186557992
#
# Cost at iteration 998 = 36.671762564221105
#
# Cost at iteration 999 = 36.66462062155274
#
# Cost at iteration 1000 = 36.65747602282486
#
# [[ 4.66568259]
#  [ 2.41806628]
#  [ 1.91956693]
#  [16.68313681]
#  [23.6191955 ]
#  [15.98626708]
#  [23.51929628]
#  [23.65479044]
#  [23.95411803]
#  [23.29217408]
#  [19.58829366]
#  [ 3.14849361]
#  [19.83546076]
#  [21.2491613 ]
#  [22.80162702]
#  [23.57187684]
#  [23.90676743]
#  [23.36401818]
#  [22.37207675]
#  [21.1229318 ]
#  [18.07236564]
#  [23.54573271]
#  [20.24644889]
#  [22.58378341]
#  [22.83711361]
#  [23.5364533 ]
#  [23.7974722 ]
#  [24.0280454 ]
#  [22.90278828]
#  [21.52107471]
#  [22.89618088]
#  [23.31144922]
#  [22.78006435]
#  [23.70146472]
#  [20.59163684]
#  [18.74451097]
#  [23.57932388]
#  [23.98016163]
#  [23.08583524]
#  [22.71962799]
#  [21.91512833]
#  [22.78655979]
#  [23.28986107]
#  [23.26851632]
#  [23.20707366]
#  [23.47466767]
#  [23.16691795]
#  [23.62987194]
#  [24.22743325]
#  [23.93356266]
#  [23.81028136]]

# %%
#Question 2
#predict the values for Boston House prices dataset
num_iters = 1000                                                                  
learning_rate = 0.03
layer_sizes=[7,5,5,1]
df =  pd.read_csv('seeds.csv')
df.head()
n=df.shape[1]               
m=df.shape[0]               

x_train=np.array(df.iloc[:int(0.9*m),:n-1])      
y_train=np.array(df.iloc[:int(0.9*m),-1])          
x_test=np.array(df.iloc[int(0.9*m):,:n-1])      
y_test=np.array(df.iloc[int(0.9*m):,-1])         
params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)
y_predict = predict(x_test,params)
print(y_predict)
